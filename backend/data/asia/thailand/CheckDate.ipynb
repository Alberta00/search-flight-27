# %%
import pandas as pd

# โหลดไฟล์ CSV
df = pd.read_csv("flightsfrom_BKK_2026-12-11.csv")

# ทำให้ชื่อคอลัมน์เป็นตัวเล็กและลบช่องว่าง
df.columns = df.columns.str.strip().str.lower()

# นับจำนวนเที่ยวบินตาม direction
dept_count = (df['direction'] == 'departure').sum()
arriv_count = (df['direction'] == 'arrival').sum()

print(f"จำนวนเที่ยวบินขาออก (Dept.): {dept_count}")
print(f"จำนวนเที่ยวบินขาเข้า (Arriv.): {arriv_count}")
# Out:
# จำนวนเที่ยวบินขาออก (Dept.): 513
# จำนวนเที่ยวบินขาเข้า (Arriv.): 511
